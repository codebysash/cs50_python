# %% [markdown]
# # Introduction to Jupyter Notebooks
#
# * Write and execute code
# * Add text, images, links
#
# ![montepython.jpg](attachment:montepython.jpg)
#
# ## Two Views
#
# * File system view
# * Jupyter Notebook
#
# ### File system view
#
# * View folders and files like in Windows Explorer/Mac Finder
# * Create new folders and text files, and notebooks
#
# ### Jupyter Notebook
#
# * Where code/text are written
#
#
# ## Jupyter Notebook Basics
#
# * Everything is a **cell**
# * Two primary types of cells
#     * Code cells
#     * Markdown cells
# * Selected cell - outlined in blue or green
#
# ### Code cells
#
# * Where you write and execute Python code
# * Have the word `In[ ]` to the left
#
# ### Markdown cells
#
# * Where you write Markdown, a simple plain-text language to add text, links, images, etc... to your notebook
# * No `In[ ]` to the left
#
# ### Your first Python code
#
# * Add two numbers together by writing `158 + 498` in the cell below
# * **Execute the cell** by pressing **shift + enter**

# %% [markdown]
# ## Edit Mode vs Command Mode
#
# Jupyter Notebook cells are always in one of two modes: **edit** or **command** mode. When in edit mode:
#
# * Cells are outlined in **green**
# * Cells have a blinking cursor in them
# * Typing results in plain text inside the cell
#
# When in command mode:
#
# * Cells are outlined in **blue**
# * Cells do not have a blinking cursor and there is nowhere to type
# * The keys have special meanings

# %% [markdown]
# ## Changing between edit and command Mode
#
# * Press **ESC** once to enter **command** mode.
# * Press **enter** to go to **edit** mode

# %% [markdown]
# ## Changing modes in a markdown cell
#
# * Press **enter** or double click to go to edit mode
# * Press **ESC** to enter command mode
# * Press **shift + enter** to execute markdown

# %% [markdown]
# ## Command Mode Keyboard Shortcuts
#
# * Up/Down arrows - move between cells
# * A - add cell above
# * B - add cell below
# * X - delete cell
# * M - convert to markdown cell
# * Y - convert to code cell

# %% [markdown]
# ### Some other cell

# %% [markdown]
# ## Using your mouse and the dropdown menus
#
# ### Keep hands on the keyboard

# %% [markdown]
# ### Some other cell

# %% [markdown]
# ## Other Notebook Tips
#
# Execute with **ctrl + enter** or **cmd + enter** to execute and stay in the current cell

# %% [markdown]
# Executing cells with no output

# %% [markdown]
# Only last line of cell is output
#
# * Exception with the `print` function

# %% [markdown]
# ## Markdown Basics
#
# * `#` - Headers
# * `*` - bullet points

# %% [markdown]
# ## Exiting the browser tab
#
# * Go to localhost:8888

# %% [markdown]
# ## Completing exercises

# %% [markdown]
# ### Exercise 1
# <span  style="color:green; font-size:16px">What is 489 plus 143?</span>

# %% [markdown]
# ### Exercise 2
# <span  style="color:green; font-size:16px">Some exercise here that is in the way!</span>

# %% [markdown]
# ## Creating a new notebook
#
# * In the notebook, **File** and then **New Notebook**
# * In the file system view, click the **New** dropdown menu and then a new **Python 3** notebook

# %% [markdown]
# ## Jupyter Notebook Extensions
#
# * Extra features for your notebook - https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/index.html
# * Installed with - `conda install -c conda-forge jupyter_contrib_nbextensions`
# * In the file system view - click on **Nbextensions** tab
# * Click checkbox at top, "disable configuration for nbextensions without explicit compatibility"
# * I use **spellchecker** and **Skip-Traceback**
# * Don't use too many extensions

# %% [markdown]
# ## Jupyter Notebook Summary
#
# * Two kinds of cells
#     * Markdown - a plain-text language with a small set of commands for creating text, images, links
#     * Code - only understands Python code. Has `In[ ]` to the left
# * Two cell modes
#     * Edit - Blinking cursor inside, allows you to edit cell contents, outlined in green
#     * Command - Keys command the notebook, outlined in blue
# * Selected cell - always one cell selected. Outlined in green or blue
# * Keyboard Shortcuts
#     * shift + enter - execute cell and move to the cell below
#     * ctrl/cmd + enter - execute cell and go into command mode in current cell
#     * esc - activate command mode
#     * enter - activate edit mode
#     * A - insert cell above
#     * B - insert cell below
#     * X - delete cell
#     * M - convert to markdown cell
#     * Y - convert to code cell
# * Markdown basics
#     * `#` - headers
#     * `*` - bullet points

# %% [markdown]
# ## Shutting Down Jupyter
#
# * **ctrl + C**
